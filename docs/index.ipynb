# %% [markdown]
# # Home

# %% [markdown]
# <hr style="border:2px solid grey">

# %% [markdown]
# ## Welcome

# %% [markdown]
# <hr style="border:2px solid grey">

# %% [markdown]
# ## About these course notes

# %% [markdown]
# <hr style="border:2px solid grey">

# %% [markdown]
# ## Authors

# %% [markdown]
# <hr style="border:2px solid grey">

# %% [markdown]
# ## Found a mistake?
